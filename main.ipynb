# %%
import os
import json

ROOTDIR = "/Users/thomasburton/Desktop/facebook-messenger-analysis/Minority_Data/"

# %%
# get all file names in directory
files = os.listdir(ROOTDIR)

# get all message file names
message_files = []
for file in files:
    if 'message_' in file:
        message_files.append(file)
print(message_files)

# taking a peek at what keys we have in the data
file = open(ROOTDIR + "message_3.json")
data = json.load(file)
print(data.keys())
# Out:
# ['message_2.json', 'message_3.json', 'message_8.json', 'message_4.json', 'message_5.json', 'message_9.json', 'message_6.json', 'message_7.json', 'message_1.json']
# dict_keys(['participants', 'messages', 'title', 'is_still_participant', 'thread_type', 'thread_path', 'magic_words', 'image'])

# %%
#data['magic_words']

# %%
#pip install emoji --upgrade

# %%
#import emoji
#print(emoji.emojize('â\x9d¤'))
print('ð\x9f¤£'.encode('latin1').decode('utf8'))
# Out:
# 🤣

# %%
# get names of all participants in the chat
participants = []

for file in message_files:
    file = open(ROOTDIR + file)
    data = json.load(file)
    people = data['participants']
    for person in people:
        if person['name'] not in participants:
            participants.append(person['name'])

# %%
participants
# Out:
# ['Eli Russo',
#  'Thomas Burton',
#  'Michael Schmidt',
#  'Shaan Singh',
#  'Kevin Huang',
#  'Mathew Antony',
#  'Dylan Priest']

# %%
import pandas as pd

messages = pd.DataFrame(data['messages'])
messages
# Out:
#           sender_name   timestamp_ms  \
# 0       Thomas Burton  1645477980756
# 1       Thomas Burton  1645477979259
# 2       Thomas Burton  1645477967510
# 3       Thomas Burton  1645477964693
# 4           Eli Russo  1645477412343
# ...               ...            ...
# 9995  Michael Schmidt  1640484152968
# 9996  Michael Schmidt  1640484139249
# 9997        Eli Russo  1640483793553
# 9998      Shaan Singh  1640483787120
# 9999      Shaan Singh  1640483783351
#
#                                                content     type  is_unsent  \
# 0                                            True king  Generic      False
# 1                      I knew he wouldnt take it badly  Generic      False
# 2                                        He fucks w it  Generic      False
# 3                   He liked our comments ð¤£ð¤£ð¤£  Generic      False
# 4        I also donât follow him so thatâs awkward  Generic      False
# ...                                                ...      ...        ...
# 9995  Nick Alfonso is at Christmas dinner with Ariyana  Generic      False
# 9996                                               Eli  Generic      False
# 9997                                               NaN  Generic       True
# 9998                                               NaN  Generic       True
# 9999                                               NaN  Generic       True
#
#      reactions photos audio_files videos share gifs  call_duration sticker
# 0          NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# 1          NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# 2          NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# 3          NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# 4          NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# ...        ...    ...         ...    ...   ...  ...            ...     ...
# 9995       NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# 9996       NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# 9997       NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# 9998       NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
# 9999       NaN    NaN         NaN    NaN   NaN  NaN            NaN     NaN
#
# [10000 rows x 13 columns]

# %%
data
# Out:
# {'participants': [{'name': 'Eli Russo'},
#   {'name': 'Thomas Burton'},
#   {'name': 'Michael Schmidt'},
#   {'name': 'Shaan Singh'},
#   {'name': 'Kevin Huang'},
#   {'name': 'Mathew Antony'},
#   {'name': 'Dylan Priest'}],
#  'messages': [{'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645477980756,
#    'content': 'True king',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645477979259,
#    'content': 'I knew he wouldnt take it badly',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645477967510,
#    'content': 'He fucks w it',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645477964693,
#    'content': 'He liked our comments ð\x9f¤£ð\x9f¤£ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645477412343,
#    'content': 'I also donâ\x80\x99t follow him so thatâ\x80\x99s awkward',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645477275860,
#    'content': 'Shohei Ohtani reacted ð\x9f\x91\x8e to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645477210092,
#    'content': 'Iâ\x80\x99m a Ryan Dinh private supporter',
#    'reactions': [{'reaction': 'ð\x9f\x91\x8e', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x91\x8e', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645477177084,
#    'content': 'Weâ\x80\x99re hyping him up idiot',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645477163731,
#    'content': 'Didnâ\x80\x99t know supporting a squad legend was bullying',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645477145210,
#    'content': 'Lame af for that',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645477091097,
#    'content': 'Pussy',
#    'reactions': [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645477042833,
#    'content': 'Because my bullying is more private ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645477031473,
#    'content': 'I will enjoy the show but will not comment',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476961048,
#    'content': 'Dominic Fike reacted ð\x9f¤£ to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476945617,
#    'content': 'ð\x9f¤£ð\x9f¤£',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476944311,
#    'content': 'I commented',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476882835,
#    'content': '@Thomas Burton wya',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476852106,
#    'content': 'â\x80\x9cThis pic is four years old wtfâ\x80\x9d',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476840795,
#    'content': 'Heâ\x80\x99s probably so confused rn',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476814408,
#    'content': 'Ok mr. gays are loud',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Thomas Burton'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Thomas Burton'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476777655,
#    'content': 'Yâ\x80\x99all bullies man ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476775823,
#    'content': 'Posted',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476745298,
#    'content': 'Ok I got u mike',
#    'reactions': [{'reaction': 'â\x9d¤', 'actor': 'Michael Schmidt'},
#     {'reaction': 'â\x9d¤', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476739610,
#    'content': 'I better see my comment being hyped up',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476718177,
#    'content': 'Thatâ\x80\x99s out of pocket ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476663913,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/274033444_978625436108943_3866983235667917684_n_978625422775611.jpg',
#      'creation_timestamp': 1645476661}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476648523,
#    'content': 'Support the cause',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476647038,
#    'content': 'Shohei Ohtani reacted â\x9d¤ to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476626957,
#    'content': 'OH MY GOD',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476597563,
#    'content': 'Enjoy these',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476589379,
#    'content': 'Fine Iâ\x80\x99ll start us off',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476588793,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273992861_340567607958261_1479993227635733804_n_340567604624928.jpg',
#      'creation_timestamp': 1645476584},
#     {'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273062326_437890344789409_1753016152659861803_n_437890341456076.jpg',
#      'creation_timestamp': 1645476584},
#     {'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273024949_1022001978355536_4884689201565584039_n_1022001975022203.jpg',
#      'creation_timestamp': 1645476584},
#     {'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273815139_892516824808816_7840874891834269103_n_892516818142150.jpg',
#      'creation_timestamp': 1645476584},
#     {'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273199374_276286314641656_7279792067563964850_n_276286311308323.jpg',
#      'creation_timestamp': 1645476584},
#     {'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273740051_1115464832542777_336851227261555598_n_1115464825876111.jpg',
#      'creation_timestamp': 1645476587},
#     {'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273810289_280443827551194_4509680891778995245_n_280443824217861.jpg',
#      'creation_timestamp': 1645476586},
#     {'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/272875230_3430761577150679_2426477415753519798_n_3430761570484013.jpg',
#      'creation_timestamp': 1645476586},
#     {'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/274086427_741299833666564_2787974222374253014_n_741299830333231.jpg',
#      'creation_timestamp': 1645476584}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Thomas Burton'},
#     {'reaction': 'â\x9d¤', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Thomas Burton'},
#     {'reaction': 'â\x9d¤', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476571367,
#    'content': 'Yes me too',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476567548,
#    'content': 'Iâ\x80\x99m down to all comment',
#    'reactions': [{'reaction': 'ð\x9f\x91\x8d', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x91\x8d', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476567386,
#    'content': '100%',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476565500,
#    'content': 'And Iâ\x80\x99ll back u',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476562962,
#    'content': 'U do it',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476561524,
#    'content': 'Doesnâ\x80\x99t rlly matter',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476557701,
#    'content': 'Nah like anyone',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476551412,
#    'content': 'Eli does that ceap too',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476548995,
#    'content': 'Ur looking at me',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476545203,
#    'content': 'When u say one of us',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476527309,
#    'audio_files': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/audio/audioclip16454765260009892_1368374430290187.mp4',
#      'creation_timestamp': 1645476526}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476521437,
#    'content': 'Like no hesitation',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476516782,
#    'content': 'Thomas get us started Iâ\x80\x99ll 100% back u',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476507669,
#    'content': 'Iâ\x80\x99m\nDown',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476471518,
#    'content': 'Basically Ryan Dinh',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476463765,
#    'videos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/videos/video1645476463_683420556030535.mp4',
#      'creation_timestamp': 1645476463,
#      'thumbnail': {'uri': 'messages/inbox/minorityleague_jh8hq00how/videos/video1645476463_683420556030535.mp4'}}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476456088,
#    'content': 'YES',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476444418,
#    'content': 'Are those hairy arms?',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476437278,
#    'audio_files': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/audio/audioclip16454764360005619_1282969332215513.mp4',
#      'creation_timestamp': 1645476436}],
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476422949,
#    'content': 'Iâ\x80\x99ll try to find it but it was legendary',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476409955,
#    'content': 'Top 5 insta pics ever',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476409833,
#    'content': 'Me and shaan still had the greatest exchange ever with that pic',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476400820,
#    'content': 'That pic is so cold',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476364655,
#    'content': 'Cooler than Joe Burrow',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476364585,
#    'content': 'Imma unsend my messages just in case itâ\x80\x99s too tucked up',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476356976,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273988209_383204713186563_9395630479095124_n_383204706519897.jpg',
#      'creation_timestamp': 1645476355}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476323975,
#    'content': 'Ryan Dinh knew what we was doing in that pic',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476319868,
#    'content': 'Cuz I got convinced like idiot',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476309389,
#    'content': 'And I genuinely was worried she hated me',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476308693,
#    'content': 'Shohei Ohtani reacted ð\x9f\x93\xa0 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476302441,
#    'content': 'That pic still the coldest pic in the game',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476301758,
#    'content': 'I was friends w her',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476298177,
#    'content': 'Dude no',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476256070,
#    'content': 'A king',
#    'reactions': [{'reaction': 'â\x9d¤', 'actor': 'Michael Schmidt'},
#     {'reaction': 'â\x9d¤', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476251068,
#    'content': 'I love that guy',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476246612,
#    'content': 'And Iâ\x80\x99m okay with that',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645476239452,
#    'content': 'Ryan Dihnâ\x80\x99s whereabouts continues to elude the public',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476227463,
#    'content': 'And you made me ask her if she thought it was awkward',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476211206,
#    'content': 'I blame Mathew',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476205460,
#    'content': 'Iâ\x80\x99m so fucked for that I thought she wanted me',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645476196940,
#    'content': 'I still canâ\x80\x99t believe I hit on Michelle',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476183402,
#    'content': 'Imma need to deliberate with the council on that',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476163692,
#    'content': 'Whenever i see her and sheâ\x80\x99s late I say â\x80\x9cIâ\x80\x99ve been waiting patientlyâ\x80\x9d',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476141738,
#    'content': 'Bro Iâ\x80\x99m still not over Hudson telling michele â\x80\x9cIâ\x80\x99ve been waiting. Patientlyâ\x80\x9d',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476132312,
#    'content': 'Is that fax or am I messed up?',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476071970,
#    'content': 'Like no need to scream all the time',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476066801,
#    'type': 'Generic',
#    'is_unsent': True},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476058671,
#    'content': 'Bc William is gay',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476052920,
#    'content': 'Gay people?',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645476037704,
#    'content': 'Dude thatâ\x80\x99s another thing I shouldâ\x80\x99ve ranted about yesterday',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476009555,
#    'content': 'Eli rn',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645476005969,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273486748_4982379028522385_1421411334324471394_n_431317912121904.jpg',
#      'creation_timestamp': 1645476005}],
#    'reactions': [{'reaction': 'ð\x9f\x98\x82', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Kevin Huang'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x82', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Kevin Huang'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645475972574,
#    'content': 'Heâ\x80\x99s so loud for no reason Iâ\x80\x99m just trynna do hw',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645475972396,
#    'content': 'Bro thereâ\x80\x99s a dude here who talks exactly like William from invincible',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645475947450,
#    'content': 'Iâ\x80\x99ve never seen a white dude that fast in my life',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645475855643,
#    'content': 'Absolute fax',
#    'reactions': [{'reaction': 'â\x9d¤', 'actor': 'Michael Schmidt'},
#     {'reaction': 'â\x9d¤', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645473912099,
#    'content': 'I love Poofesureð\x9f\x98\x82',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Kevin Huang'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Kevin Huang'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645473881666,
#    'content': 'Prime Gareth Bale was top 5',
#    'reactions': [{'reaction': 'ð\x9f§¢', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f§¢', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645473874786,
#    'content': 'Iâ\x80\x99m not afraid to say this and Ik shaan will agree',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645473743814,
#    'content': 'Shohei Ohtani reacted ð\x9f\x98\x86 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645473417836,
#    'content': 'Also itâ\x80\x99s whatever I knew all the cheat codes in bowling to get a perfect score for that game that ends with 100 pins',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645473382252,
#    'content': 'Like Iâ\x80\x99m trynna throw it dammit',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645473377392,
#    'content': 'When the bowling ball just drops I used to lose my shit',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645473330206,
#    'content': 'Then we wonâ\x80\x99t get caught off guard ever again',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645473318222,
#    'content': 'So we know when to expect a trip',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645473313971,
#    'content': 'Imma write a damn python script that is connected to Heleneâ\x80\x99s bank account to monitor her flight transactions',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645473283831,
#    'content': 'Helene is moving to New York with Mia mosing',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Kevin Huang',
#    'timestamp_ms': 1645473258673,
#    'content': 'https://youtu.be/SvvFYg3852E',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'}],
#    'share': {'link': 'https://www.youtube.com/watch?v=SvvFYg3852E'},
#    'type': 'Share',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645470942165,
#    'content': 'Tom Holland reacted ð\x9f\x98\x82 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645470191794,
#    'content': 'Hope she enjoyed her freaging stay',
#    'reactions': [{'reaction': 'ð\x9f\x98\x82', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f\x98\x82', 'actor': 'Shaan Singh'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645470184248,
#    'content': 'And Helene is flying from Boston again',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645470177953,
#    'content': 'Bang',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645428919246,
#    'content': 'Kelly Oubre reacted ð\x9f\x98\x86 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645428170751,
#    'content': 'Squiggly ass eyebrows',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Shaan Singh'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645428158841,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/274307753_258490916466062_3584224179264997543_n_258490913132729.jpg',
#      'creation_timestamp': 1645428155}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645428045719,
#    'content': 'Bruh',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645427475587,
#    'content': 'This shit had me dying today ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645427463134,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273759075_749398326037493_5133465527331997475_n_749398319370827.jpg',
#      'creation_timestamp': 1645427459}],
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645421228434,
#    'content': 'Heâ\x80\x99s hella lucky regardless',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645420635250,
#    'content': 'Thereâ\x80\x99s nooo way',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645420632704,
#    'content': 'ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645420630367,
#    'content': 'Thatâ\x80\x99s def staged bro',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645420479328,
#    'content': 'grayteeeee',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645419597738,
#    'content': 'Yeah that dude got farther with a girl on accident than I ever did ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645419157311,
#    'content': 'was that on accident?? ð\x9f\x98\x82ð\x9f\x98\x82',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645417389035,
#    'content': 'Lucky man',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645417383851,
#    'content': 'You sent an attachment.',
#    'share': {'link': 'https://www.tiktok.com/@meliodas_dominicana_xd/video/7064680872997326086?_r=1&_d=secCgYIASAHKAESPgo8zUQ%2BZlD2SSwJwHpzhtMvZ6AatfzTX%2BGaQPGTHKOfa1EaMr5b%2FOGDKaF6am93c6KlHb4MsgYwVppSNXmBGgA%3D&checksum=6c0f7702b2607be9252598d1d41bdbca67d43f74a670b1e996263c9f63e15f76&language=en&preview_pb=0&sec_user_id=MS4wLjABAAAAMHi0BxPgK7Ndw8KZ-hW-7zj_BPR4B5u_qKHG_-TgalzNqjClOx1o2PcqfSeAfIlV&share_app_id=1233&share_item_id=7064680872997326086&share_link_id=E5DDA835-9A22-47F9-B2F4-6E9BF0461463&source=h5_m&timestamp=1645417377&tt_from=messenger&u_code=db972d1l486i25&user_id=6802403474215797766&utm_campaign=client_share&utm_medium=ios&utm_source=messenger&improve_sharing_social=v1'},
#    'type': 'Share',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645416524987,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273907108_300828432039792_1100796686257232216_n_300828425373126.jpg',
#      'creation_timestamp': 1645416523}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645416521819,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/274246758_1036461880559608_1522818413096123258_n_1036461873892942.jpg',
#      'creation_timestamp': 1645416519}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645416247976,
#    'content': 'Dominic Fike reacted ð\x9f\x93\xa0 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645416243299,
#    'content': 'That was wild those 5 threes he missed ruins the percentage',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Thomas Burton'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Thomas Burton'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645416238793,
#    'content': 'I thjnk thatâ\x80\x99s why they go easy',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645416234421,
#    'content': 'Yeah but u also donâ\x80\x99t want anyone to get hurt',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645416199597,
#    'content': 'Bro saw it was in Cleveland and went into 2017-18 finals mode lmao',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645416099743,
#    'content': 'Steph Fr owns Cleveland wow',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645416053954,
#    'content': 'Facts',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645415916415,
#    'content': 'It would be so fun to watch',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645415912402,
#    'content': 'Itâ\x80\x99ll never happen but imagine the whole game was played like the last 24 points',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645415778327,
#    'content': 'Fitting that LeBron made the last shot',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645415711736,
#    'content': 'Dominic Fike reacted ð\x9f\x93\xa0 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645415663151,
#    'content': 'Shohei Ohtani reacted ð\x9f\x93\xa0 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645415649587,
#    'content': 'But the game was kinda mid as usual except for curry carrying',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645415636031,
#    'content': 'Last quarter of the all star game was dope ngl',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Thomas Burton'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Thomas Burton'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645414514015,
#    'content': 'Steph wtf',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645414104483,
#    'content': 'Yea lol',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645413973382,
#    'content': 'Sue bird',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645413774793,
#    'content': '^ mcgregor voice',
#    'reactions': [{'reaction': 'ð\x9f\x98®', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98®', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645413769999,
#    'content': 'Who tf is that',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645413626368,
#    'content': 'Sheâ\x80\x99s so fine',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645413623829,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273903758_482747829956854_8505241129488212030_n_482747823290188.jpg',
#      'creation_timestamp': 1645413622}],
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645413516176,
#    'content': 'Man ð\x9f\x92\x80',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645413511478,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273916394_990785228209939_4320266496303096507_n_990785221543273.jpg',
#      'creation_timestamp': 1645413510}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645413495637,
#    'content': 'Bro only has made 3sð\x9f\x98\xad',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645413455586,
#    'content': 'This is the greatest all star steak Iâ\x80\x99ve ever seen for a player',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645413435504,
#    'content': 'Holy fuck',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645413413667,
#    'content': 'Wtf is going on',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645413410995,
#    'content': 'Curry is insane rn',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645413240791,
#    'content': 'Why was Adam lefkoe a 75th anniversary gm',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645410581723,
#    'content': 'Shohei Ohtani reacted ð\x9f\x98\x86 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Kevin Huang',
#    'timestamp_ms': 1645410241811,
#    'content': 'Mr bean goated show',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Kevin Huang',
#    'timestamp_ms': 1645410234592,
#    'content': 'I remember that scene',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Kevin Huang',
#    'timestamp_ms': 1645410224848,
#    'content': 'Absentee reacted ð\x9f\x98\x86 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645410092304,
#    'content': 'Me when Ayesha is in my way',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645410088961,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271443884_911753839486957_2641446138108489077_n_636277697658636.gif'}],
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Kevin Huang'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Kevin Huang'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645410059419,
#    'content': 'but hes christian and ur super, um, not',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645410048704,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/270215893_333101545118779_913638059356510869_n_1461469584268716.gif'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645410019374,
#    'content': 'Iâ\x80\x99m gonna do UTB with curry',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645409846629,
#    'content': 'and it was amazing',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645409843334,
#    'content': 'nah but they showed her ass',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645409800871,
#    'content': 'Me to the producers cause sheâ\x80\x99s not wearing a bikini',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645409789542,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271444311_467672618103558_4304028608946596244_n_1053094378884178.gif'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645409751871,
#    'content': 'shes byooooooodddeefol',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645409747800,
#    'content': 'nah shes not hot',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645409731051,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271389111_4790753227698263_1212979216553903521_n_234850612100575.gif'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645409688019,
#    'content': 'god id dtroy her',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645409482230,
#    'content': 'Curry ð\x9f\x98©ð\x9f\x98©',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645409327797,
#    'content': 'Midgins',
#    'reactions': [{'reaction': 'ð\x9f¤¡', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤¡', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645409272624,
#    'content': 'Wiggins ð\x9f\x98©',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645409260769,
#    'content': 'yea fax ð\x9f\x98\x82',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645409259260,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/256295906_1613986122315141_5747582242894280191_n_1773863632803988.gif'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645409245529,
#    'content': 'Just the wrong Ball',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645409241315,
#    'content': 'Bro we have DeBallZach tonight',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645409228240,
#    'content': 'Demar ð\x9f\x98©ð\x9f\x98©ð\x9f\x98©ð\x9f\x98©',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645409222510,
#    'content': 'Husky legend',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645409210659,
#    'content': 'Dejounteð\x9f\x98©',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645409161065,
#    'content': 'Boner city for u probably',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645408845489,
#    'content': 'and kevin hart isnt funny in it',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645408840906,
#    'content': 'best interview ive ever seen',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645408836047,
#    'content': 'https://www.youtube.com/watch?v=IXjqR1clKIk',
#    'share': {'link': 'https://www.youtube.com/watch?v=IXjqR1clKIk'},
#    'type': 'Share',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645407335135,
#    'content': 'Above the rim',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645407309253,
#    'content': 'Crazy',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645407306878,
#    'content': 'Ja*',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645407304735,
#    'content': 'Ha is so bouncy',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645407074886,
#    'content': 'Bruh why does that ALWAYS happen',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645407062144,
#    'content': 'The video chat ended.',
#    'call_duration': 0,
#    'type': 'Call',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645407053567,
#    'content': 'Shohei Ohtani joined the video chat.',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645407049770,
#    'content': 'Shohei Ohtani started a video chat.',
#    'call_duration': 0,
#    'type': 'Call',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406982750,
#    'content': 'Oh god LeBron',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406972966,
#    'content': 'Wtf how tall is Monty Williams',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406905623,
#    'content': 'Enjoy Dwayne Wade then loser',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406897406,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271389973_366456101956181_1206656440319316017_n_3145290752416148.gif'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406892191,
#    'content': '720pstreams clutching up',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406877350,
#    'content': 'Also I have a feeling Ja winning MVP today',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406875719,
#    'content': 'Tbs',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406873309,
#    'content': 'I donâ\x80\x99t have rbs',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406865600,
#    'content': 'Go to TBS',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406863137,
#    'content': 'Bro donâ\x80\x99t watch those fuckers',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406852809,
#    'content': 'Shut up Wadeð\x9f\x98\x82',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406847014,
#    'content': 'â\x80\x9cMy nickname for Giannis is zone, Bc heâ\x80\x99s always zoned inâ\x80\x9d',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406535439,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271443788_4528102687312152_8734526602278423300_n_1317559202057494.gif'}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406504529,
#    'content': 'Shohei Ohtani reacted ð\x9f\x98\x86 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406498381,
#    'content': 'Looks like she got electrocuted',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406464814,
#    'content': 'We need the lady from the SB',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406455105,
#    'content': 'Nah this American National anthem sucks',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406431892,
#    'content': 'ð\x9f\x87®ð\x9f\x87±',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406388999,
#    'videos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/videos/video1645406388_527882985214937.mp4',
#      'creation_timestamp': 1645406382,
#      'thumbnail': {'uri': 'messages/inbox/minorityleague_jh8hq00how/videos/video1645406388_527882985214937.mp4'}}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406378341,
#    'content': 'Sheesh',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406355569,
#    'content': 'This guy killing it Ngl heâ\x80\x99s popping off',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406239962,
#    'content': 'Better not happen again tho',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406233923,
#    'content': 'Yeah he gets a making it about himself pass for today',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406220157,
#    'content': 'Iâ\x80\x99ll give it a pass this time',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406210700,
#    'content': 'Plus itâ\x80\x99s in Cleveland',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645406194818,
#    'content': 'Ok lebron made it about himself when being introduced but I canâ\x80\x99t get mad cause he was hella hyped',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406164205,
#    'content': 'Booed tf outta curry love to see it',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645406029305,
#    'content': 'Booed tf outta Harden love to see it',
#    'reactions': [{'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x93\xa0', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645405977054,
# ...
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645321654576,
#    'content': 'the normal one was just as bad',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645321524416,
#    'content': 'This skills challenge sucks booty',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Thomas Burton',
#    'timestamp_ms': 1645321224665,
#    'content': 'Mudblood is the equivalent of the n word in the Harry Potter universe',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645320597520,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271277506_4597528463677862_4960810433666409965_n_3141386856092648.gif'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645320586332,
#    'content': 'https://youtu.be/vzNTHEXlw3o',
#    'share': {'link': 'https://www.youtube.com/watch?v=vzNTHEXlw3o'},
#    'type': 'Share',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645319870356,
#    'content': 'AND THEYRE MAKING A THUNDER PLAYER TAKE THAT SHOT IM SICK',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645319853331,
#    'content': 'Bro youâ\x80\x99re kidding',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645319735624,
#    'content': 'lol michael can never catch a break ð\x9f\x98\x82',
#    'reactions': [{'reaction': 'ð\x9f\x98\x9e', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f\x98\x9e', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645319522176,
#    'content': 'They added a Damien lillard 3pt spot for the skills challenge itâ\x80\x99s where he hit the buzzer against OKC ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645319469873,
#    'content': 'Bro wtf are these new skills challenge format? This is fucking stupid',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645319436456,
#    'content': 'All star weekend jusr keeps getting better',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645319433262,
#    'content': 'Grayte',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645319424744,
#    'content': 'Awesome Dwayne Wade is commentating',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645318352976,
#    'content': 'GGMU',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645318350398,
#    'content': 'Weâ\x80\x99re beating Leeds tomorrow Ronny is going off',
#    'reactions': [{'reaction': 'ð\x9f¤¡', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤¡', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645318235648,
#    'content': 'IM ANGRY',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645318230189,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271489312_508245873850539_8271056209721143715_n_625989298470129.gif'}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645318186250,
#    'content': 'â\x80\x9cItâ\x80\x99s jusr Sabrinaâ\x80\x9d Iâ\x80\x99m dying ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645318183027,
#    'content': 'Stats is pissing me off',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645318178859,
#    'content': 'No',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645318164085,
#    'content': 'Yooo chill ð\x9f¤£ð\x9f¤£',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645318116922,
#    'content': 'Her forehead takes up 85 percent of her face',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645318099653,
#    'content': 'No like the Rutenburg twins comments always piss me off â\x80\x9cgoddessâ\x80\x9d like shut up itâ\x80\x99s just Sabrina',
#    'reactions': [{'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Dylan Priest'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645318072953,
#    'content': 'No Rachel not at all sheâ\x80\x99s very ugly',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645318062919,
#    'content': 'OMG stunning',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645318057381,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/255573046_604405820826811_8448991033252341671_n_305350384807118.gif'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645317975316,
#    'content': 'Like no she isnâ\x80\x99t gorg or stunning â\x9c¨shes ugly af',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645317953244,
#    'content': 'Especially sorority girl comments when they complement someone who isnâ\x80\x99t pretty',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645317950980,
#    'content': 'Theyâ\x80\x99re just not funny',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645317923049,
#    'content': 'Dickriders on insta are the worst',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645317849312,
#    'content': 'Theyâ\x80\x99re so fucking annoying like let me enjoy the comments the first 15 comments are just them',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645317825165,
#    'content': 'Him and lilmabu can die',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645317817412,
#    'content': 'Dude',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645317349366,
#    'content': 'Like he literally does this on every Kanye post itâ\x80\x99s so annoying',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645317338520,
#    'content': 'Iâ\x80\x99ve never seen a bigger Kanye dick rider in my life',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645317328420,
#    'content': 'Bro this dude is so fucking annoying',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645317324252,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273262693_1316264718882617_1684509662480720508_n_1316264712215951.jpg',
#      'creation_timestamp': 1645317322}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645317078974,
#    'content': 'Dude Dylan wants Jalen green to aggressively penetrate his butthole',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645317023598,
#    'audio_files': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/audio/audioclip16453170230003135_642483690335689.mp4',
#      'creation_timestamp': 1645317023}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Shaan Singh',
#    'timestamp_ms': 1645316961874,
#    'content': 'Tom Holland reacted ð\x9f\x98\x82 to your message ',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645316956333,
#    'content': 'Yeah letâ\x80\x99s just say it hasnâ\x80\x99t started very well',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645316927168,
#    'content': 'War',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645316923848,
#    'content': 'Me waiting for Eliâ\x80\x99s Tik Tok wat',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645316911518,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271439802_270082061778963_677234714253893838_n_491584492488227.gif'}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645316248503,
#    'content': 'All I know CJ heating up',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645316238613,
#    'content': '@Michael comment on the tok',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645316216694,
#    'gifs': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/gifs/271291641_460712892283454_8343935304823476661_n_682394712953748.gif'}],
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f\x98\x86', 'actor': 'Michael Schmidt'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645316162507,
#    'content': 'I feel like Cole Anthony gonna win over Jalen green',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645316147723,
#    'content': 'Dylan I will try to follow ur foot steps',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Dylan Priest',
#    'timestamp_ms': 1645316145148,
#    'content': 'jalen green and patty mills baby',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645316077583,
#    'content': 'Start a war',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Eli Russo',
#    'timestamp_ms': 1645316075580,
#    'content': 'Schmidt Iâ\x80\x99m posting on tiktok rn',
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645316043248,
#    'content': 'HUH',
#    'reactions': [{'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'},
#     {'reaction': 'ð\x9f¤£', 'actor': 'Eli Russo'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   {'sender_name': 'Michael Schmidt',
#    'timestamp_ms': 1645316037484,
#    'photos': [{'uri': 'messages/inbox/minorityleague_jh8hq00how/photos/273872967_957736531803811_3562052295018022468_n_957736525137145.jpg',
#      'creation_timestamp': 1645316036}],
#    'reactions': [{'reaction': 'ð\x9f¤¡', 'actor': 'Shaan Singh'},
#     {'reaction': 'ð\x9f¤¡', 'actor': 'Shaan Singh'}],
#    'type': 'Generic',
#    'is_unsent': False},
#   ...],
#  'title': 'Minority League',
#  'is_still_participant': True,
#  'thread_type': 'RegularGroup',
#  'thread_path': 'inbox/minorityleague_jh8hq00how',
#  'magic_words': [{'magic_word': 'Astros',
#    'creation_timestamp_ms': 1635183438257,
#    'animation_emoji': 'ð\x9f\x97\x91'},
#   {'magic_word': 'Dame',
#    'creation_timestamp_ms': 1635055295759,
#    'animation_emoji': 'ð\x9f\x98¡'},
#   {'magic_word': 'Deeloosh',
#    'creation_timestamp_ms': 1635054995918,
#    'animation_emoji': 'ð\x9f¥\x92'},
#   {'magic_word': 'Dodgers',
#    'creation_timestamp_ms': 1639023912093,
#    'animation_emoji': 'ð\x9f\x98\x8d'},
#   {'magic_word': 'Dodgerz',
#    'creation_timestamp_ms': 1635113853579,
#    'animation_emoji': 'ð\x9f\x90\x90'},
#   {'magic_word': 'Drake is the goat',
#    'creation_timestamp_ms': 1635054737543,
#    'animation_emoji': 'ð\x9f§¢'},
#   {'magic_word': 'Duchdown Beelz',
#    'creation_timestamp_ms': 1635055247314,
#    'animation_emoji': 'ð\x9f\x98\x9e'},
#   {'magic_word': 'Dude I got it from the Portland Pickles',
#    'creation_timestamp_ms': 1635055141744,
#    'animation_emoji': 'ð\x9f¥\x92'},
#   {'magic_word': 'Dylan',
#    'creation_timestamp_ms': 1635113980151,
#    'animation_emoji': 'ð\x9f\x98\xa0'},
#   {'magic_word': 'Eli is hot',
#    'creation_timestamp_ms': 1635054544405,
#    'animation_emoji': 'ð\x9f\x98\x8d'},
#   {'magic_word': 'Elis a virgin',
#    'creation_timestamp_ms': 1635055061666,
#    'animation_emoji': 'ð\x9f¤®'},
#   {'magic_word': 'Eloosh',
#    'creation_timestamp_ms': 1635054888132,
#    'animation_emoji': 'ð\x9f\x87®ð\x9f\x87±'},
#   {'magic_word': 'Ghae ghae pannae',
#    'creation_timestamp_ms': 1635055073102,
#    'animation_emoji': 'ð\x9f\x91\x80'},
#   {'magic_word': 'Go Ducks',
#    'creation_timestamp_ms': 1635054616020,
#    'animation_emoji': 'ð\x9f\x90º'},
#   {'magic_word': 'Grabsters McGee',
#    'creation_timestamp_ms': 1635055105839,
#    'animation_emoji': 'ð\x9f\x91º'},
#   {'magic_word': 'Grayted cheese',
#    'creation_timestamp_ms': 1635389672378,
#    'animation_emoji': 'ð\x9f§\x80'},
#   {'magic_word': 'Hudson banged shaans crush Ashley',
#    'creation_timestamp_ms': 1635055119144,
#    'animation_emoji': 'ð\x9f\x98ª'},
#   {'magic_word': 'Iâ\x80\x99m horny',
#    'creation_timestamp_ms': 1635054798527,
#    'animation_emoji': 'ð\x9f\x98\x88'},
#   {'magic_word': 'Jewish',
#    'creation_timestamp_ms': 1635054855114,
#    'animation_emoji': 'ð\x9f¤¥'},
#   {'magic_word': 'Lily Burton',
#    'creation_timestamp_ms': 1635054916719,
#    'animation_emoji': 'ð\x9f\x98©'},
#   {'magic_word': 'Mariners',
#    'creation_timestamp_ms': 1635054814827,
#    'animation_emoji': 'ð\x9f\x8f\x86'},
#   {'magic_word': 'OKC',
#    'creation_timestamp_ms': 1635054656163,
#    'animation_emoji': 'ð\x9f\x92©'},
#   {'magic_word': 'PACKERS!',
#    'creation_timestamp_ms': 1635054930978,
#    'animation_emoji': 'ð\x9f¤¬'},
#   {'magic_word': 'Raiders',
#    'creation_timestamp_ms': 1635054707605,
#    'animation_emoji': 'ð\x9f¤¡'},
#   {'magic_word': 'Schgmeed',
#    'creation_timestamp_ms': 1635055510703,
#    'animation_emoji': 'ð\x9f\x92ª'},
#   {'magic_word': 'Shaan is sus',
#    'creation_timestamp_ms': 1635054703088,
#    'animation_emoji': 'ð\x9f\x92\x85'},
#   {'magic_word': 'Thunder',
#    'creation_timestamp_ms': 1639629604487,
#    'animation_emoji': 'â\x9c¡ï¸\x8f'},
#   {'magic_word': 'Who needs to get laid?',
#    'creation_timestamp_ms': 1635055309198,
#    'animation_emoji': 'ð\x9f\x99\x8bâ\x80\x8dâ\x99\x82ï¸\x8f'},
#   {'magic_word': 'eli',
#    'creation_timestamp_ms': 1635113923386,
#    'animation_emoji': 'ð\x9f¤¥'},
#   {'magic_word': 'elis gay',
#    'creation_timestamp_ms': 1635054484386,
#    'animation_emoji': 'ð\x9f\x8d\x86'},
#   {'magic_word': 'mikes a bitch',
#    'creation_timestamp_ms': 1635113886247,
#    'animation_emoji': 'ð\x9f\x93\xa0'},
#   {'magic_word': 'rip melissa',
#    'creation_timestamp_ms': 1635054662128,
#    'animation_emoji': 'ð\x9f¦\x86'}],
#  'image': {'uri': 'messages/photos/69823807_473106596865896_535851892354318336_n_473106593532563.png',
#   'creation_timestamp': 1568178508}}
